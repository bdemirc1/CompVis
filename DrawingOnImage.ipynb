# %% [markdown]
# # Drawing on Images

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def imshow(title = "Image", image = None, size = 10):
    w, h = image.shape[0], image.shape[1]
    aspect_ratio = w/h
    plt.figure(figsize=(size * aspect_ratio,size))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

# %%
blank_img = np.zeros((512,512,3), np.uint8)

# %%
imshow("Black Canvas - RGB Color", blank_img)

# %%
# cv2.line(image, starting cordinates, ending cordinates, color, thickness)
cv2.line(blank_img, (0,0), (512,512), (0,255,255), 5)
imshow("Black Canvas With Diagonal Line", blank_img)

# %% [raw]
# # cv2.rectangle(image, starting vertex, opposite vertex, color, thickness = -1 filled)
# cv2.rectangle(blank_img, (200,200), (300,300), (255,0,0), -1)
# imshow("Black canvas with filled rectangle", blank_img)

# %% [markdown]
# ## Put Text

# %% [markdown]
# ## cv2.putText(image, 'Text to Display', bottom left starting point, Font, Font Size, Color, Thickness)
#
# Available Fonts
#
# FONT_HERSHEY_SIMPLEX, FONT_HERSHEY_PLAIN
# FONT_HERSHEY_DUPLEX,FONT_HERSHEY_COMPLEX
# FONT_HERSHEY_TRIPLEX, FONT_HERSHEY_COMPLEX_SMALL
# FONT_HERSHEY_SCRIPT_SIMPLEX
# FONT_HERSHEY_SCRIPT_COMPLEX

# %%
blank_img2 = np.zeros((512,512,3), np.uint8)
ourString =  'Hello World!'
cv2.putText(blank_img2, ourString, (10,250), cv2.FONT_HERSHEY_SCRIPT_COMPLEX, 3, (40,200,0), 4)
imshow("Messing with some text", blank_img2)
